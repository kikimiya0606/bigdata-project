# %%
import pandas as pd
df = pd.read_csv("csic2010_requests.csv")
df.head()
# Out:
#        label method                                   url http_version  \
# 0  Anomalous   POST  /tienda1/publico/caracteristicas.jsp     HTTP/1.1
# 1     Normal    GET  /tienda1/miembros/imagenes/ogono.jpg     HTTP/1.1
# 2     Normal   POST           /tienda1/publico/vaciar.jsp     HTTP/1.1
# 3     Normal    GET                    /tienda1/index.jsp     HTTP/1.1
# 4     Normal    GET            /tienda1/global/titulo.jsp     HTTP/1.1
#
#              host                                         user_agent  \
# 0  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 1  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 2  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 3  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
# 4  localhost:8080  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...
#
#      pragma cache_control                                             accept  \
# ...

# %%
df['label'].value_counts()
# Out:
# label
# Normal       5895
# Anomalous    4105
# Name: count, dtype: int64

# %%
df['url_length'] = df['url'].str.len()
df.groupby('label')['url_length'].describe()
# Out:
#             count       mean        std   min   25%   50%   75%    max
# label
# Anomalous  4066.0  77.487703  94.576060   1.0  27.0  33.0  91.0  865.0
# Normal     5895.0  50.535199  61.990671  18.0  27.0  29.0  37.0  332.0
